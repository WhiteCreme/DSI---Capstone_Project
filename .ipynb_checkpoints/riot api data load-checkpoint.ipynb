# %%
import pandas as pd
import numpy as np
import requests
import json
from pandas.io.json import json_normalize
from ratelimit import limits, sleep_and_retry
import requests

# %%
pip install ratelimit
# Out:
# Collecting ratelimit
#   Downloading https://files.pythonhosted.org/packages/ab/38/ff60c8fc9e002d50d48822cc5095deb8ebbc5f91a6b8fdd9731c87a147c9/ratelimit-2.2.1.tar.gz
# Building wheels for collected packages: ratelimit
#   Building wheel for ratelimit (setup.py): started
#   Building wheel for ratelimit (setup.py): finished with status 'done'
#   Created wheel for ratelimit: filename=ratelimit-2.2.1-cp37-none-any.whl size=5899 sha256=396af152e36e89c764f7805b399d23b412eb3fbb7ce2502c03428a14c1c1234b
#   Stored in directory: C:\Users\sang\AppData\Local\pip\Cache\wheels\05\d9\82\3c6044cf1a54aab9151612458446d9b17a38416869e1b1d9b8
# Successfully built ratelimit
# Installing collected packages: ratelimit
# Successfully installed ratelimit-2.2.1
# Note: you may need to restart the kernel to use updated packages.

# %%
two_minutes = 120


@sleep_and_retry
@limits(calls=90, period=two_minutes)
def call_api(url):
    response = requests.get(url)

    if response.status_code != 200:
        raise Exception('API response: {}'.format(response.status_code))
    return response

# %%
# Global Variables
KEY = 'RGAPI-e8ab8c77-0e55-4562-814f-f7e64301e8d0'
API_BASE = 'https://na1.api.riotgames.com/'
API_BASE_REGION = 'https://americas.api.riotgames.com/'
 
TIERS = ['IRON' , 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'DIAMOND']
DIVISIONS = ['I'] # , 'II', 'III', 'IV']
TIERS_LIST = []
for tier in TIERS:
  for division in DIVISIONS:
    TIER_DIVISION = tier + '/' + division
    TIERS_LIST.append(TIER_DIVISION)

TIER_URLS = []
for tiers_divis in TIERS_LIST: 
  url = API_BASE + 'tft/league/v1/entries/' + tiers_divis + '?page=1&api_key=' + KEY
  TIER_URLS.append(url)

# %%
TIER_URLS
# Out:
# ['https://na1.api.riotgames.com/tft/league/v1/entries/IRON/I?page=1&api_key=RGAPI-e8ab8c77-0e55-4562-814f-f7e64301e8d0',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/BRONZE/I?page=1&api_key=RGAPI-e8ab8c77-0e55-4562-814f-f7e64301e8d0',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/SILVER/I?page=1&api_key=RGAPI-e8ab8c77-0e55-4562-814f-f7e64301e8d0',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/GOLD/I?page=1&api_key=RGAPI-e8ab8c77-0e55-4562-814f-f7e64301e8d0',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/PLATINUM/I?page=1&api_key=RGAPI-e8ab8c77-0e55-4562-814f-f7e64301e8d0',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/DIAMOND/I?page=1&api_key=RGAPI-e8ab8c77-0e55-4562-814f-f7e64301e8d0']

# %%
# Get list of each summoner in each tier
tier_frames = []

for url in TIER_URLS:
  REQUEST_TIERS = call_api(url)
  tier_data = json.loads(REQUEST_TIERS.text)
  tier_df = json_normalize(tier_data)
  tier_frames.append(tier_df)
divisions = pd.concat(tier_frames, ignore_index=True, sort=True)

# %%
divisions['division_tier'] = divisions['tier'] + '_' + divisions['rank'] 
divisions
# Out:
#       freshBlood  hotStreak  inactive                              leagueId  \
# 0          False      False     False  bba31c20-0f0a-11ea-9d15-0292af83ade6
# 1          False      False     False  38ef74e0-2049-11ea-af12-e2e7dba1695f
# 2          False      False     False  3e06330f-c4f3-4a08-a497-e81f6df10588
# 3          False      False     False  f4694230-0bb0-11ea-b9fc-eeb4098ebaa0
# 4          False      False     False  13e67db0-19e1-11ea-8ce1-0256c6254f55
# ...          ...        ...       ...                                   ...
# 1225       False      False     False  89049da3-9661-4022-8493-2bcc80f5dacb
# 1226       False      False     False  38fc30af-6a55-4dd5-9c4d-30ccfe4e5f9e
# 1227       False      False     False  4dbb9270-3104-11ea-b978-da957a0ba512
# 1228       False      False     False  d3354c0b-1e5c-412a-9d41-7b9e63892ee9
# 1229       False      False     False  81c15780-1b65-11ea-9a33-362bc5ddecfc
#
#       leaguePoints  losses   queueType rank  \
# 0               94       5  RANKED_TFT    I
# 1               41      22  RANKED_TFT    I
# 2               13       9  RANKED_TFT    I
# 3               11       6  RANKED_TFT    I
# 4               30       5  RANKED_TFT    I
# ...            ...     ...         ...  ...
# 1225             0     432  RANKED_TFT    I
# 1226            50     248  RANKED_TFT    I
# 1227             0     246  RANKED_TFT    I
# 1228            25     383  RANKED_TFT    I
# 1229            50     235  RANKED_TFT    I
#
#                                             summonerId      summonerName  \
# 0     yuST92qI7G8ZiMWVBzHJ6e2xONnD6Rc1R-AfC3IU-FEsK8xY     Thesmokingpun
# 1     cClZh8jH4gTqTlFoz_fYFO6OQwLvWEvyJaCx515J_g6Ml3GX   TwitchDrDescend
# 2     8VN_E8UqdztjMGB_OU5taldKe8rYdKqbQeQNJij7aa8Bx8BS            Iskoog
# 3     Ild9nWTxkyF8XWYHIbSKkO4l_HuWKnc-oCBhnMwm2txdJVdu  paybackisthename
# 4     cID8eSPpX2QVsydzTIdzHtXD1GBIjf_kTsl3zIXIctjPOspl      Dasheng Tian
# ...                                                ...               ...
# 1225  qVAN_SH1Io3x96qU9XBEADlCSXLHuIB-pi4F88VHPwdNSeKT        Miss Lunar
# 1226  Ah6O486MQd5LMQCDL5-QgXw7PS822RjLvRTwKgBIs72WyKq1            Igoaff
# 1227  GKcNbHuCmrv7ctx1PsyX5GUWt2TWG_ky8j9Ub8mEE5PFXRQZ            h3li0n
# 1228  MUibO7QmaPCwU9TXAAag32IlZVXBoQ-9AizuzFNLiEqSYKNB         1000water
# 1229  IrMF-MpkB_aiAMNARMGKZ9NK3QEtQmUUHklOfRoeJ1uddWT6  twitch tv guffee
#
#          tier  veteran  wins division_tier
# 0        IRON    False     0        IRON_I
# 1        IRON    False     0        IRON_I
# 2        IRON    False     0        IRON_I
# 3        IRON    False     0        IRON_I
# 4        IRON    False     2        IRON_I
# ...       ...      ...   ...           ...
# 1225  DIAMOND    False    59     DIAMOND_I
# 1226  DIAMOND    False    40     DIAMOND_I
# 1227  DIAMOND    False    63     DIAMOND_I
# 1228  DIAMOND    False    78     DIAMOND_I
# 1229  DIAMOND    False    47     DIAMOND_I
#
# [1230 rows x 14 columns]

# %%
divisions
# Out:
#       freshBlood  hotStreak  inactive                              leagueId  \
# 0          False      False     False  bba31c20-0f0a-11ea-9d15-0292af83ade6
# 1          False      False     False  38ef74e0-2049-11ea-af12-e2e7dba1695f
# 2          False      False     False  3e06330f-c4f3-4a08-a497-e81f6df10588
# 3          False      False     False  f4694230-0bb0-11ea-b9fc-eeb4098ebaa0
# 4          False      False     False  13e67db0-19e1-11ea-8ce1-0256c6254f55
# ...          ...        ...       ...                                   ...
# 1225       False      False     False  89049da3-9661-4022-8493-2bcc80f5dacb
# 1226       False      False     False  38fc30af-6a55-4dd5-9c4d-30ccfe4e5f9e
# 1227       False      False     False  4dbb9270-3104-11ea-b978-da957a0ba512
# 1228       False      False     False  d3354c0b-1e5c-412a-9d41-7b9e63892ee9
# 1229       False      False     False  81c15780-1b65-11ea-9a33-362bc5ddecfc
#
#       leaguePoints  losses   queueType rank  \
# 0               94       5  RANKED_TFT    I
# 1               41      22  RANKED_TFT    I
# 2               13       9  RANKED_TFT    I
# 3               11       6  RANKED_TFT    I
# 4               30       5  RANKED_TFT    I
# ...            ...     ...         ...  ...
# 1225             0     432  RANKED_TFT    I
# 1226            50     248  RANKED_TFT    I
# 1227             0     246  RANKED_TFT    I
# 1228            25     383  RANKED_TFT    I
# 1229            50     235  RANKED_TFT    I
#
#                                             summonerId      summonerName  \
# 0     yuST92qI7G8ZiMWVBzHJ6e2xONnD6Rc1R-AfC3IU-FEsK8xY     Thesmokingpun
# 1     cClZh8jH4gTqTlFoz_fYFO6OQwLvWEvyJaCx515J_g6Ml3GX   TwitchDrDescend
# 2     8VN_E8UqdztjMGB_OU5taldKe8rYdKqbQeQNJij7aa8Bx8BS            Iskoog
# 3     Ild9nWTxkyF8XWYHIbSKkO4l_HuWKnc-oCBhnMwm2txdJVdu  paybackisthename
# 4     cID8eSPpX2QVsydzTIdzHtXD1GBIjf_kTsl3zIXIctjPOspl      Dasheng Tian
# ...                                                ...               ...
# 1225  qVAN_SH1Io3x96qU9XBEADlCSXLHuIB-pi4F88VHPwdNSeKT        Miss Lunar
# 1226  Ah6O486MQd5LMQCDL5-QgXw7PS822RjLvRTwKgBIs72WyKq1            Igoaff
# 1227  GKcNbHuCmrv7ctx1PsyX5GUWt2TWG_ky8j9Ub8mEE5PFXRQZ            h3li0n
# 1228  MUibO7QmaPCwU9TXAAag32IlZVXBoQ-9AizuzFNLiEqSYKNB         1000water
# 1229  IrMF-MpkB_aiAMNARMGKZ9NK3QEtQmUUHklOfRoeJ1uddWT6  twitch tv guffee
#
#          tier  veteran  wins division_tier
# 0        IRON    False     0        IRON_I
# 1        IRON    False     0        IRON_I
# 2        IRON    False     0        IRON_I
# 3        IRON    False     0        IRON_I
# 4        IRON    False     2        IRON_I
# ...       ...      ...   ...           ...
# 1225  DIAMOND    False    59     DIAMOND_I
# 1226  DIAMOND    False    40     DIAMOND_I
# 1227  DIAMOND    False    63     DIAMOND_I
# 1228  DIAMOND    False    78     DIAMOND_I
# 1229  DIAMOND    False    47     DIAMOND_I
#
# [1230 rows x 14 columns]

# %%
# Get summoner name from divisions data frame / keeping it at 5 for now for testing
summoner_names = divisions.loc[ :, 'summonerName' ]

# %%
summoner_names
# Out:
# 0          Thesmokingpun
# 1        TwitchDrDescend
# 2                 Iskoog
# 3       paybackisthename
# 4           Dasheng Tian
#               ...
# 1225          Miss Lunar
# 1226              Igoaff
# 1227              h3li0n
# 1228           1000water
# 1229    twitch tv guffee
# Name: summonerName, Length: 1230, dtype: object

# %%
summoner_frames = []

for summoner in summoner_names:
  summoner_url = API_BASE + 'tft/summoner/v1/summoners/by-name/' + summoner + '?api_key=' + KEY
  REQUEST_NAME = call_api(summoner_url)
  summoner_data = json.loads(REQUEST_NAME.text)
  summoner_df = json_normalize(summoner_data)
  summoner_frames.append(summoner_df)
join_summoners = pd.concat(summoner_frames, ignore_index=True, sort=True)

# %%
join_summoners = join_summoners.merge(divisions[['summonerName','division_tier']],left_on='name', right_on = 'summonerName')

# %%
join_summoners.head()
# Out:
#                                            accountId  \
# 0  zI283lT_AmT46PYA4ryvDu6_pCEQWelYXsDEFnkVuY46eK...
# 1  HoX-vMezy19MFPStaMIWJkSJo7TqzKUiiZcdRLQJNiLNfj...
# 2  JpUFYXoEICpGy_pc_bpIF834PYUkAxCZU_hNvNPs9Zedy4...
# 3  L1syM0T2vG7fFnguMokQk2F_XmRwby3YtItKvx-naNEIFp...
# 4  A70edyG8emCOgQguKKxXH_UCI1Uw2ypDg7Ogai9khr4sHj...
#
#                                                  id              name  \
# 0  yuST92qI7G8ZiMWVBzHJ6e2xONnD6Rc1R-AfC3IU-FEsK8xY     Thesmokingpun
# 1  cClZh8jH4gTqTlFoz_fYFO6OQwLvWEvyJaCx515J_g6Ml3GX   TwitchDrDescend
# 2  8VN_E8UqdztjMGB_OU5taldKe8rYdKqbQeQNJij7aa8Bx8BS            Iskoog
# 3  Ild9nWTxkyF8XWYHIbSKkO4l_HuWKnc-oCBhnMwm2txdJVdu  paybackisthename
# 4  cID8eSPpX2QVsydzTIdzHtXD1GBIjf_kTsl3zIXIctjPOspl      Dasheng Tian
#
#    profileIconId                                              puuid  \
# 0           4080  Ki1KO62ygcycSVm6LoqHuxrL2CMzEF-bU2uMKrms9pPUog...
# 1           1437  Qo8MH3V2TR24SNwj15PHwdLnmls1zV2TshFuMzLrwoK30-...
# 2           3791  rOLjK2bI7u1Vgf0UW6N57SMSE26R_-Q5sNj5CCYLNPhzCu...
# 3           4088  PhT-sWyWBFP7e9ks7BgJ-jJ4tbI1Pu9g_YqQWf4v-pWQJb...
# 4           3546  NaxTv335VOuWqE47Re-qtlj6IFINYFe9mO0pH_lYndCdlF...
#
#     revisionDate  summonerLevel      summonerName division_tier
# 0  1577783118000            174     Thesmokingpun        IRON_I
# 1  1583209489000             27   TwitchDrDescend        IRON_I
# 2  1583265443000             38            Iskoog        IRON_I
# 3  1583110821000            147  paybackisthename        IRON_I
# 4  1580409701000             13      Dasheng Tian        IRON_I

# %%
# Get puuid from summoners data frame
summoner_puuid = join_summoners.loc[ : , 'puuid' ]

# %%
summoner_puuid
# Out:
# 0       Ki1KO62ygcycSVm6LoqHuxrL2CMzEF-bU2uMKrms9pPUog...
# 1       Qo8MH3V2TR24SNwj15PHwdLnmls1zV2TshFuMzLrwoK30-...
# 2       rOLjK2bI7u1Vgf0UW6N57SMSE26R_-Q5sNj5CCYLNPhzCu...
# 3       PhT-sWyWBFP7e9ks7BgJ-jJ4tbI1Pu9g_YqQWf4v-pWQJb...
# 4       NaxTv335VOuWqE47Re-qtlj6IFINYFe9mO0pH_lYndCdlF...
#                               ...
# 1225    DYjiQdjHWTVN2XlJ6nV34hncu9D1m-B1pzTTtlzkMcw9ls...
# 1226    us2v-tssgxbOQ0FuHRzd-aGwsfB2ln6FstsXjWR4U80Lkr...
# 1227    CKyOy5ZYY4dNJJSV0fRg-B1sQpguLlPCk1w2dYE5AnXD5D...
# 1228    Ls9eFAANhqziAVS6GBCkuVZxOMFBnjjKl3rEhZQFAB116N...
# 1229    XfKiI7h3NVoK_v9A46CDoxw4uo8b6LkO-V_H-d5aHGLii1...
# Name: puuid, Length: 1230, dtype: object

# %%
game_id_frames = []
match_count = '1'

for puuid in summoner_puuid:
  match_url = API_BASE_REGION + '/tft/match/v1/matches/by-puuid/' + puuid + '/ids?count=' + match_count + '&api_key=' + KEY
  REQUEST_MATCH = call_api(match_url)
  match_data = json.loads(REQUEST_MATCH.text)
  match_df = pd.Series(match_data)
  game_id_frames.append(match_df)
game_id_data = pd.concat(game_id_frames, ignore_index=True, sort=True)

# %%
# need to convert to series
game_id_list = game_id_data.loc[:]

# %%
game_id_list
# Out:
# 0       NA1_3220227240
# 1       NA1_3313188067
# 2       NA1_3302506161
# 3       NA1_3313864862
# 4       NA1_3281128705
#              ...
# 1225    NA1_3313846499
# 1226    NA1_3313937393
# 1227    NA1_3313751669
# 1228    NA1_3283002319
# 1229    NA1_3304505515
# Length: 1230, dtype: object

# %%
match_info_frames = []
match_count = '2'

for game_id in game_id_list:
  result_url = API_BASE_REGION + 'tft/match/v1/matches/' + game_id + '?api_key=' + KEY
  REQUEST_RESULT = call_api(result_url)
  result_data = json.loads(REQUEST_RESULT.text)
  result_df = json_normalize(result_data)
  match_info_frames.append(result_df)
match_info_data = pd.concat(match_info_frames, ignore_index=True, sort=True)

# %%
match_info_data
# Out:
#       info.game_datetime  info.game_length  \
# 0          1574977840977       2028.678955
# 1          1583209488712       1885.422363
# 2          1582241300313       1823.497559
# 3          1583269972996       1979.711426
# 4          1580409699694       2011.223267
# ...                  ...               ...
# 1225       1583270915027       2082.954834
# 1226       1583277873977       2415.291748
# 1227       1583258942269       2207.861328
# 1228       1580549517675       2060.932861
# 1229       1582415489063       2020.099976
#
#                                       info.game_version  \
# 0     Version 9.23.299.3089 (Nov 25 2019/17:12:47) [...
# 1     Version 10.4.308.9400 (Feb 14 2020/17:25:03) [...
# 2     Version 10.4.308.9400 (Feb 14 2020/17:25:03) [...
# 3     Version 10.4.308.9400 (Feb 14 2020/17:25:03) [...
# 4     Version 10.2.305.4739 (Jan 21 2020/15:48:11) [...
# ...                                                 ...
# 1225  Version 10.4.308.9400 (Feb 14 2020/17:25:03) [...
# 1226  Version 10.4.308.9400 (Feb 14 2020/17:25:03) [...
# 1227  Version 10.4.308.9400 (Feb 14 2020/17:25:03) [...
# 1228  Version 10.2.305.4739 (Jan 21 2020/15:48:11) [...
# 1229  Version 10.4.308.9400 (Feb 14 2020/17:25:03) [...
#
#                                       info.participants  info.queue_id  \
# 0     [{'companion': {'content_ID': 'b5cab758-7194-4...           1100
# 1     [{'companion': {'content_ID': '8c27f67c-90b3-4...           1100
# 2     [{'companion': {'content_ID': 'c4508a6f-123d-4...           1100
# 3     [{'companion': {'content_ID': 'd07d0b76-cd0d-4...           1100
# 4     [{'companion': {'content_ID': '5897ad9f-4665-4...           1100
# ...                                                 ...            ...
# 1225  [{'companion': {'content_ID': '19671861-ecbd-4...           1100
# 1226  [{'companion': {'content_ID': '52fbe476-4038-4...           1090
# 1227  [{'companion': {'content_ID': '3f425bda-6328-4...           1100
# 1228  [{'companion': {'content_ID': '1b860b17-e947-4...           1100
# 1229  [{'companion': {'content_ID': '5897ad9f-4665-4...           1100
#
#       info.tft_set_number metadata.data_version metadata.match_id  \
# 0                       2                     3    NA1_3220227240
# 1                       2                     4    NA1_3313188067
# 2                       2                     4    NA1_3302506161
# 3                       2                     4    NA1_3313864862
# 4                       2                     4    NA1_3281128705
# ...                   ...                   ...               ...
# 1225                    2                     4    NA1_3313846499
# 1226                    2                     4    NA1_3313937393
# 1227                    2                     4    NA1_3313751669
# 1228                    2                     4    NA1_3283002319
# 1229                    2                     4    NA1_3304505515
#
#                                   metadata.participants
# 0     [WwAaD7WefPc_IIK298IpwEWE-FYn2s3kpLM9kSdsaxGTA...
# 1     [DPM1MPKwrBtNsXNARpLMQpQ9XPkspQgFuOdw1qhu8W5F3...
# 2     [2K2P4x46UgHOhGTI32nxjcT_PahCXUisXEowi6vbatO0O...
# 3     [plODai2a7lalVCepZefOt1MIkaJzkKAHCzb3hqbXVJa0B...
# 4     [NaxTv335VOuWqE47Re-qtlj6IFINYFe9mO0pH_lYndCdl...
# ...                                                 ...
# 1225  [hhdh_BMFgRLJ7gGXJsCVn_CzyamUiXt_6tMTBdfaf2YLy...
# 1226  [BKwhWqfBcHT3JK7gzuNVhnuu8Q6ZVZ9q9IRkbQIEKMjy6...
# 1227  [1ZtRJ2gX5Ea5vYEm8fohLuFyCGtsuiNC_s-livSqwamWb...
# 1228  [qOUpEDbkfF_GdI4lSJc0MhSaoDdovg9mhWty_J3G8MLOt...
# 1229  [Bj7ywAQ-BSDaMBBtHXeDm3BBQ10L2drF2MKf1jNoU8VcR...
#
# [1230 rows x 9 columns]

# %%
match_info_data.columns
# Out:
# Index(['info.game_datetime', 'info.game_length', 'info.game_version',
#        'info.participants', 'info.queue_id', 'info.tft_set_number',
#        'metadata.data_version', 'metadata.match_id', 'metadata.participants'],
#       dtype='object')

# %%
pd.options.display.max_seq_items = 2000

# %%
match_info_data['info.participants'][2]
# Out:
# [{'companion': {'content_ID': 'c4508a6f-123d-443f-84e7-e40ea526cd7f',
#    'skin_ID': 10,
#    'species': 'PetPenguKnight'},
#   'gold_left': 2,
#   'last_round': 27,
#   'level': 6,
#   'placement': 7,
#   'players_eliminated': 0,
#   'puuid': '2K2P4x46UgHOhGTI32nxjcT_PahCXUisXEowi6vbatO0OKKH77lGgjPgUHu-wwS_AkcEuNsqbXlJtA',
#   'time_eliminated': 1490.4603271484375,
#   'total_damage_to_players': 42,
#   'traits': [{'name': 'Berserker',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Inferno',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'Light',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'Set2_Ranger',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'Shadow',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 2},
#    {'name': 'Summoner',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 2}],
#   'units': [{'character_id': 'TFT2_Malzahar',
#     'items': [14],
#     'name': 'Malzahar',
#     'rarity': 1,
#     'tier': 3},
#    {'character_id': 'TFT2_Varus',
#     'items': [23],
#     'name': 'Varus',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Kindred',
#     'items': [33, 10203, 39],
#     'name': 'Kindred',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT2_Sion',
#     'items': [],
#     'name': 'Sion',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT2_Yorick',
#     'items': [9, 14],
#     'name': 'Yorick',
#     'rarity': 3,
#     'tier': 1},
#    {'character_id': 'TFT2_Annie',
#     'items': [10203],
#     'name': 'Annie',
#     'rarity': 3,
#     'tier': 2}]},
#  {'companion': {'content_ID': 'b1299bd0-b2e3-4b60-bdf6-a66d38e5ba14',
#    'skin_ID': 10,
#    'species': 'PetGhosty'},
#   'gold_left': 20,
#   'last_round': 30,
#   'level': 8,
#   'placement': 5,
#   'players_eliminated': 0,
#   'puuid': 'S2epufVOhw1nY99Ihvg4uCA8cm7W72M_sNA1u4eJJoda3OBgRBHF_KZ4Jh77J06SblcS2vgv5u7FJQ',
#   'time_eliminated': 1659.28271484375,
#   'total_damage_to_players': 69,
#   'traits': [{'name': 'Druid',
#     'num_units': 2,
#     'style': 3,
#     'tier_current': 1,
#     'tier_total': 1},
#    {'name': 'Inferno',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'Mage',
#     'num_units': 6,
#     'style': 3,
#     'tier_current': 2,
#     'tier_total': 2},
#    {'name': 'Ocean',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'Set2_Assassin',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Shadow',
#     'num_units': 2,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Summoner',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Woodland',
#     'num_units': 3,
#     'style': 3,
#     'tier_current': 1,
#     'tier_total': 2}],
#   'units': [{'character_id': 'TFT2_Ivern',
#     'items': [10203, 59],
#     'name': 'Ivern',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT2_Vladimir',
#     'items': [10203, 16, 26],
#     'name': 'Vladimir',
#     'rarity': 0,
#     'tier': 3},
#    {'character_id': 'TFT2_LeBlanc',
#     'items': [],
#     'name': 'Leblanc',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Malzahar',
#     'items': [48, 59, 2],
#     'name': 'Malzahar',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Neeko',
#     'items': [],
#     'name': 'Neeko',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Syndra',
#     'items': [],
#     'name': 'Syndra',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Veigar',
#     'items': [37],
#     'name': 'Veigar',
#     'rarity': 2,
#     'tier': 3},
#    {'character_id': 'TFT2_Brand',
#     'items': [],
#     'name': 'Brand',
#     'rarity': 3,
#     'tier': 1}]},
#  {'companion': {'content_ID': '5897ad9f-4665-4372-8f3e-6c878adb8918',
#    'skin_ID': 1,
#    'species': 'PetTFTAvatar'},
#   'gold_left': 2,
#   'last_round': 33,
#   'level': 9,
#   'placement': 1,
#   'players_eliminated': 3,
#   'puuid': 'Fm8qPLnED4IRN_mlNNKyyv6nQz9Kr3Bb_mDA5LeJS3vaQ8JBdcEB_oDxJGs1xV5Px7lwXNu_OUC-kA',
#   'time_eliminated': 1815.00927734375,
#   'total_damage_to_players': 218,
#   'traits': [{'name': 'Berserker',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 2},
#    {'name': 'Electric',
#     'num_units': 3,
#     'style': 3,
#     'tier_current': 2,
#     'tier_total': 3},
#    {'name': 'Poison',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 1},
#    {'name': 'Predator',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 1},
#    {'name': 'Set2_Assassin',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Set2_Glacial',
#     'num_units': 6,
#     'style': 4,
#     'tier_current': 3,
#     'tier_total': 3},
#    {'name': 'Set2_Ranger',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'Summoner',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Warden',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3}],
#   'units': [{'character_id': 'TFT2_Warwick',
#     'items': [],
#     'name': 'Warwick',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT2_Ornn',
#     'items': [10203],
#     'name': 'Ornn',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT2_Braum',
#     'items': [],
#     'name': 'Braum',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Volibear',
#     'items': [],
#     'name': 'Volibear',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_DrMundo',
#     'items': [78, 17],
#     'name': 'DrMundo',
#     'rarity': 2,
#     'tier': 1},
#    {'character_id': 'TFT2_Ezreal',
#     'items': [],
#     'name': 'Ezreal',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT2_Ezreal',
#     'items': [34, 26],
#     'name': 'Ezreal',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT2_Olaf',
#     'items': [10203, 23, 24],
#     'name': 'Olaf',
#     'rarity': 3,
#     'tier': 2},
#    {'character_id': 'TFT2_Zed',
#     'items': [55, 16],
#     'name': 'Zed',
#     'rarity': 4,
#     'tier': 2}]},
#  {'companion': {'content_ID': 'fcd5425d-9a58-43f1-bd7f-f73541e415f8',
#    'skin_ID': 13,
#    'species': 'PetTurtle'},
#   'gold_left': 7,
#   'last_round': 27,
#   'level': 7,
#   'placement': 8,
#   'players_eliminated': 0,
#   'puuid': '4lF0FdLdpa0VCzdTX3BZhnpJXizHDjxP9s04UJCHbIPfIDN-WoCWtg-GgWtiTgsR-77e32oYy4CDdg',
#   'time_eliminated': 1488.8751220703125,
#   'total_damage_to_players': 54,
#   'traits': [{'name': 'Crystal',
#     'num_units': 2,
#     'style': 3,
#     'tier_current': 1,
#     'tier_total': 2},
#    {'name': 'Inferno',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'Poison',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 1},
#    {'name': 'Predator',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 1},
#    {'name': 'Set2_Assassin',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Set2_Glacial',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'Set2_Ranger',
#     'num_units': 4,
#     'style': 2,
#     'tier_current': 2,
#     'tier_total': 3},
#    {'name': 'Summoner',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2}],
#   'units': [{'character_id': 'TFT2_Zyra',
#     'items': [10203],
#     'name': 'Zyra',
#     'rarity': 0,
#     'tier': 3},
#    {'character_id': 'TFT2_Diana',
#     'items': [10203],
#     'name': 'Diana',
#     'rarity': 0,
#     'tier': 3},
#    {'character_id': 'TFT2_Skarner',
#     'items': [5, 77, 66],
#     'name': 'Skarner',
#     'rarity': 1,
#     'tier': 3},
#    {'character_id': 'TFT2_Varus',
#     'items': [19, 23],
#     'name': 'Varus',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Ezreal',
#     'items': [],
#     'name': 'Ezreal',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT2_Twitch',
#     'items': [],
#     'name': 'Twitch',
#     'rarity': 3,
#     'tier': 2},
#    {'character_id': 'TFT2_Ashe',
#     'items': [],
#     'name': 'Ashe',
#     'rarity': 3,
#     'tier': 2}]},
#  {'companion': {'content_ID': '5897ad9f-4665-4372-8f3e-6c878adb8918',
#    'skin_ID': 1,
#    'species': 'PetTFTAvatar'},
#   'gold_left': 3,
#   'last_round': 33,
#   'level': 8,
#   'placement': 2,
#   'players_eliminated': 0,
#   'puuid': 'rOLjK2bI7u1Vgf0UW6N57SMSE26R_-Q5sNj5CCYLNPhzCuxJ3sjcFypXsSE6jHRTe_aTE1As-Iu--w',
#   'time_eliminated': 1815.00927734375,
#   'total_damage_to_players': 128,
#   'traits': [{'name': 'Berserker',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Celestial',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 1},
#    {'name': 'Electric',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'Light',
#     'num_units': 5,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'Mystic',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 2},
#    {'name': 'Set2_Blademaster',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'Set2_Ranger',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'Warden',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'Wind',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3}],
#   'units': [{'character_id': 'TFT2_Nasus',
#     'items': [10203, 77, 28],
#     'name': 'Nasus',
#     'rarity': 0,
#     'tier': 3},
#    {'character_id': 'TFT2_Ornn',
#     'items': [77],
#     'name': 'Ornn',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT2_Vayne',
#     'items': [29, 13],
#     'name': 'Vayne',
#     'rarity': 0,
#     'tier': 3},
#    {'character_id': 'TFT2_Jax',
#     'items': [],
#     'name': 'Jax',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Yasuo',
#     'items': [19, 10203, 25],
#     'name': 'Yasuo',
#     'rarity': 1,
#     'tier': 3},
#    {'character_id': 'TFT2_Aatrox',
#     'items': [99],
#     'name': 'Aatrox',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT2_Soraka',
#     'items': [],
#     'name': 'Soraka',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT2_Karma',
#     'items': [],
#     'name': '',
#     'rarity': 2,
#     'tier': 1}]},
#  {'companion': {'content_ID': '6054d70b-e401-4bec-b350-f26865700c77',
#    'skin_ID': 13,
#    'species': 'PetPenguKnight'},
#   'gold_left': 9,
#   'last_round': 33,
#   'level': 9,
#   'placement': 3,
#   'players_eliminated': 1,
#   'puuid': 'XcYNqy_tRmbkFDzD1DZagmK7Vahmhzs7Z-zE1Kc27bRtfnBPrhS8oc-9rfMEYLKv67xyCwu2o88Q3w',
#   'time_eliminated': 1808.2371826171875,
#   'total_damage_to_players': 94,
#   'traits': [{'name': 'Berserker',
#     'num_units': 6,
#     'style': 3,
#     'tier_current': 2,
#     'tier_total': 2},
#    {'name': 'Desert',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Electric',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'Inferno',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3},
#    {'name': 'Light',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'Poison',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 1},
#    {'name': 'Set2_Glacial',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'Set2_Ranger',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'Shadow',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Warden',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 3}],
#   'units': [{'character_id': 'TFT2_Nasus',
#     'items': [],
#     'name': 'Nasus',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT2_Renekton',
#     'items': [15],
#     'name': 'Renekton',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT2_Vayne',
#     'items': [25, 16, 22],
#     'name': 'Vayne',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT2_Jax',
#     'items': [17, 49, 23],
#     'name': 'Jax',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Volibear',
#     'items': [],
#     'name': 'Volibear',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Varus',
#     'items': [],
#     'name': 'Varus',
#     'rarity': 1,
#     'tier': 1},
#    {'character_id': 'TFT2_DrMundo',
#     'items': [10203],
#     'name': 'DrMundo',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT2_Sion',
#     'items': [10203],
#     'name': 'Sion',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT2_Olaf',
#     'items': [],
#     'name': 'Olaf',
#     'rarity': 3,
#     'tier': 1}]},
#  {'companion': {'content_ID': 'b1299bd0-b2e3-4b60-bdf6-a66d38e5ba14',
#    'skin_ID': 10,
#    'species': 'PetGhosty'},
#   'gold_left': 23,
#   'last_round': 27,
#   'level': 7,
#   'placement': 6,
#   'players_eliminated': 0,
#   'puuid': 'z6erN-L7nnRdBLfJCJ_Wel3f9ZrBLLwiprt-yp8l7sdIT2VFrOsMPNQO3LlZqyAJlOwGUMvMEsm6oA',
#   'time_eliminated': 1497.5606689453125,
#   'total_damage_to_players': 44,
#   'traits': [{'name': 'Mage',
#     'num_units': 3,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 2},
#    {'name': 'Mountain',
#     'num_units': 2,
#     'style': 3,
#     'tier_current': 1,
#     'tier_total': 1},
#    {'name': 'Ocean',
#     'num_units': 4,
#     'style': 3,
#     'tier_current': 2,
#     'tier_total': 3},
#    {'name': 'Set2_Assassin',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Warden',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3}],
#   'units': [{'character_id': 'TFT2_Taliyah',
#     'items': [34, 10203, 39],
#     'name': 'Taliyah',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT2_Vladimir',
#     'items': [39],
#     'name': 'Vladimir',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT2_Thresh',
#     'items': [],
#     'name': 'Thresh',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Syndra',
#     'items': [2],
#     'name': 'Syndra',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Syndra',
#     'items': [],
#     'name': 'Syndra',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_QiyanaOcean',
#     'items': [16, 10203],
#     'name': 'Qiyana',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT2_Malphite',
#     'items': [57],
#     'name': 'Malphite',
#     'rarity': 3,
#     'tier': 2}]},
#  {'companion': {'content_ID': 'c4508a6f-123d-443f-84e7-e40ea526cd7f',
#    'skin_ID': 10,
#    'species': 'PetPenguKnight'},
#   'gold_left': 2,
#   'last_round': 31,
#   'level': 8,
#   'placement': 4,
#   'players_eliminated': 2,
#   'puuid': '1Q4J4U9cr7LYSQchgzTefhHHJlUuCpRnNQ49m-6rseigc7CmVaMwC6coyYcQhpLQomPkmltHWLnxZA',
#   'time_eliminated': 1709.80419921875,
#   'total_damage_to_players': 77,
#   'traits': [{'name': 'Inferno',
#     'num_units': 7,
#     'style': 3,
#     'tier_current': 2,
#     'tier_total': 3},
#    {'name': 'Mage',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Mountain',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 1},
#    {'name': 'Set2_Assassin',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Set2_Ranger',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3},
#    {'name': 'Shadow',
#     'num_units': 1,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Summoner',
#     'num_units': 2,
#     'style': 0,
#     'tier_current': 0,
#     'tier_total': 2},
#    {'name': 'Warden',
#     'num_units': 2,
#     'style': 1,
#     'tier_current': 1,
#     'tier_total': 3}],
#   'units': [{'character_id': 'TFT2_Zyra',
#     'items': [],
#     'name': 'Zyra',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT2_Diana',
#     'items': [57],
#     'name': 'Diana',
#     'rarity': 0,
#     'tier': 2},
#    {'character_id': 'TFT2_Varus',
#     'items': [14, 10203, 11],
#     'name': 'Varus',
#     'rarity': 1,
#     'tier': 2},
#    {'character_id': 'TFT2_Kindred',
#     'items': [26, 24],
#     'name': 'Kindred',
#     'rarity': 2,
#     'tier': 2},
#    {'character_id': 'TFT2_Brand',
#     'items': [49, 10203],
#     'name': 'Brand',
#     'rarity': 3,
#     'tier': 2},
#    {'character_id': 'TFT2_Annie',
#     'items': [],
#     'name': 'Annie',
#     'rarity': 3,
#     'tier': 2},
#    {'character_id': 'TFT2_Malphite',
#     'items': [],
#     'name': 'Malphite',
#     'rarity': 3,
#     'tier': 2},
#    {'character_id': 'TFT2_Amumu',
#     'items': [39],
#     'name': '',
#     'rarity': 4,
#     'tier': 1}]}]

# %%
#df = pd.Series(data={match_info_data['info.participants'][0]})
# dct = {'A':5, 'B':4, 'C':-1}
# df['min_count'] = df['category'].map(dct)
# df = df.query('count>min_count')

participants_df = []
for num in range(len(match_info_data['info.participants'])):
    
    data = match_info_data['info.participants'][num]
    data_df = pd.DataFrame.from_dict(data)
    participants_df.append(data_df)
    game_df = pd.concat(participants_df, ignore_index=True, sort=True)


game_df
# Out:
#                                               companion  gold_left  \
# 0     {'content_ID': 'b5cab758-7194-412a-8370-908b11...          3
# 1     {'content_ID': '3fd8f774-fbf9-4ffd-aed5-79f1a8...          2
# 2     {'content_ID': 'b1299bd0-b2e3-4b60-bdf6-a66d38...          1
# 3     {'content_ID': '2e631ec1-f5ea-4e21-b57b-3b8d92...         11
# 4     {'content_ID': '2a705022-688c-4405-bee4-3598b6...         20
# ...                                                 ...        ...
# 9835  {'content_ID': '1417c8b3-9ebb-4d56-b9cf-6cb3af...          0
# 9836  {'content_ID': '5897ad9f-4665-4372-8f3e-6c878a...          1
# 9837  {'content_ID': 'b1f08eb3-c601-4ca1-a6c7-15e892...          8
# 9838  {'content_ID': '4e85b5a3-84c8-4fa4-be93-0a93ab...          1
# 9839  {'content_ID': '52fbe476-4038-432f-b94e-42914f...         22
#
#       last_round  level  placement  players_eliminated  \
# 0             33      8          4                   0
# 1             31      6          6                   0
# 2             34      7          3                   0
# 3             30      7          7                   0
# 4             33      7          5                   2
# ...          ...    ...        ...                 ...
# 9835          26      8          7                   0
# 9836          37      8          2                   3
# 9837          28      8          5                   0
# 9838          33      8          4                   1
# 9839          37      8          1                   2
#
#                                                   puuid  time_eliminated  \
# 0     WwAaD7WefPc_IIK298IpwEWE-FYn2s3kpLM9kSdsaxGTAr...      1897.483276
# 1     T56QuzTRqNPZjCw_HV07qsaLk0jsSn3EahJgBlbo76J0qz...      1769.266968
# 2     Ki1KO62ygcycSVm6LoqHuxrL2CMzEF-bU2uMKrms9pPUog...      1957.186768
# 3     5aiIUH1lI9kbERkF4IUXt7h8u_ibETAXHzF-6MUxmOLTuZ...      1692.093506
# 4     vON1Whx0BlQ7lk4SMkXcwORVZjVmgX1VI7b5lqT2RTu_uv...      1891.783081
# ...                                                 ...              ...
# 9835  XfKiI7h3NVoK_v9A46CDoxw4uo8b6LkO-V_H-d5aHGLii1...      1443.390503
# 9836  Q1KVZj1rU8IKEBBigpWk25v52SlqPc-3uatvE2Amhu-Qvl...      2011.907837
# 9837  wVg7zuNTTx49sAzX9PTSZCMPshmCMu7k8fbdLx3a19chG9...      1560.702637
# 9838  72NyuFF1_RQCk6dwYSMfX4hyRH2qzhQmprZMzWT299u5Bs...      1817.397339
# 9839  qRiCW9CpemFKsB1yO5Oea0IwswSRuSpN3UZxUA8fU-ZuTf...      2011.907837
#
#       total_damage_to_players  \
# 0                         126
# 1                          81
# 2                         108
# 3                          74
# 4                          86
# ...                       ...
# 9835                       34
# 9836                      152
# 9837                       64
# 9838                      123
# 9839                      208
#
#                                                  traits  \
# 0     [{'name': 'Berserker', 'num_units': 3, 'style'...
# 1     [{'name': 'Crystal', 'num_units': 1, 'style': ...
# 2     [{'name': 'Electric', 'num_units': 1, 'style':...
# 3     [{'name': 'Berserker', 'num_units': 6, 'style'...
# 4     [{'name': 'Alchemist', 'num_units': 1, 'style'...
# ...                                                 ...
# 9835  [{'name': 'Celestial', 'num_units': 2, 'style'...
# 9836  [{'name': 'Berserker', 'num_units': 1, 'style'...
# 9837  [{'name': 'Berserker', 'num_units': 6, 'style'...
# 9838  [{'name': 'Berserker', 'num_units': 1, 'style'...
# 9839  [{'name': 'Alchemist', 'num_units': 1, 'style'...
#
#                                                   units
# 0     [{'character_id': 'TFT2_Volibear', 'items': []...
# 1     [{'character_id': 'TFT2_Skarner', 'items': [6]...
# 2     [{'character_id': 'TFT2_Veigar', 'items': [34,...
# 3     [{'character_id': 'TFT2_Jax', 'items': [14, 29...
# 4     [{'character_id': 'TFT2_Twitch', 'items': [16,...
# ...                                                 ...
# 9835  [{'character_id': 'TFT2_Leona', 'items': [67, ...
# 9836  [{'character_id': 'TFT2_Malzahar', 'items': [3...
# 9837  [{'character_id': 'TFT2_Renekton', 'items': []...
# 9838  [{'character_id': 'TFT2_Renekton', 'items': []...
# 9839  [{'character_id': 'TFT2_Braum', 'items': [1020...
#
# [9840 rows x 11 columns]

# %%
# REPLACE PUUID WITH NAME?

#name_ = game_df['puuid'] 
#for puuid in game_df['puuid']:
#game_df['puuid'] = join_summoners['name'].map(join_summoners.set_index('name')['puuid'])

# %%
range(len(game_df['units']))

# %%
game_df_test = []
#[game_df['unit_1_character_id'][row] for row in game_df['units'][row][0]['character_id']
# game_df['unit_1_items']
# game_df['unit_1_name']
# game_df['unit_1_rarity']
# game_df['unit_1_tier']
#game_df['unit_1_character_id'] = [game_df['units'][0]['character_id'] for row in game_df['units']]

# %%
game_df

# %%
traits_data = game_df['traits']
traits_df = pd.DataFrame.from_dict(traits_data)
traits_df['traits'][0]
# Out:
# [{'name': 'Berserker',
#   'num_units': 3,
#   'style': 1,
#   'tier_current': 1,
#   'tier_total': 2},
#  {'name': 'Electric',
#   'num_units': 1,
#   'style': 0,
#   'tier_current': 0,
#   'tier_total': 3},
#  {'name': 'Metal',
#   'num_units': 1,
#   'style': 0,
#   'tier_current': 0,
#   'tier_total': 3},
#  {'name': 'Mountain',
#   'num_units': 1,
#   'style': 0,
#   'tier_current': 0,
#   'tier_total': 1},
#  {'name': 'Poison',
#   'num_units': 3,
#   'style': 3,
#   'tier_current': 1,
#   'tier_total': 1},
#  {'name': 'Predator',
#   'num_units': 3,
#   'style': 3,
#   'tier_current': 1,
#   'tier_total': 1},
#  {'name': 'Set2_Glacial',
#   'num_units': 4,
#   'style': 2,
#   'tier_current': 2,
#   'tier_total': 3},
#  {'name': 'Set2_Ranger',
#   'num_units': 1,
#   'style': 0,
#   'tier_current': 0,
#   'tier_total': 3},
#  {'name': 'Warden',
#   'num_units': 2,
#   'style': 1,
#   'tier_current': 1,
#   'tier_total': 3}]

# %%
units_data = game_df['units']
units_df = pd.DataFrame.from_dict(units_data)
units_df['units'][1]
# Out:
# [{'character_id': 'TFT2_Skarner',
#   'items': [6],
#   'name': 'Skarner',
#   'rarity': 1,
#   'tier': 2},
#  {'character_id': 'TFT2_KogMaw',
#   'items': [17, 10201],
#   'name': 'KogMaw',
#   'rarity': 0,
#   'tier': 2},
#  {'character_id': 'TFT2_Ivern',
#   'items': [33],
#   'name': 'Ivern',
#   'rarity': 0,
#   'tier': 3},
#  {'character_id': 'TFT2_Maokai',
#   'items': [69],
#   'name': 'Maokai',
#   'rarity': 0,
#   'tier': 3},
#  {'character_id': 'TFT2_RekSai',
#   'items': [45],
#   'name': 'RekSai',
#   'rarity': 1,
#   'tier': 2},
#  {'character_id': 'TFT2_Nocturne',
#   'items': [10201, 12, 2],
#   'name': 'Nocturne',
#   'rarity': 2,
#   'tier': 3}]

# %%
# join the unit name with tier value in a list separated by comma
game_df['units_name'] = [','.join([unit['name']+'_'+str(unit['tier']) for unit in units]) for units in game_df['units']]

# create dummy columns of the list of 'unit_tier' per player and add it to original df
units_df = game_df['units_name'].str.get_dummies(sep = ',')

# %%
# join the trait name with set tier value in a list separated by comma
game_df['trait_name'] = [','.join([trait['name']+'_'+str(trait['tier_current']) for trait in traits]) for traits in game_df['traits']]

# create dummy columns of the list of 'unit_tier' per player and add it to original df
traits_df = game_df['trait_name'].str.get_dummies(sep = ',')

# %%
# join the dummy columns with original game_df
game_df = game_df.join(units_df)
game_df = game_df.join(traits_df)

# %%
game_df = game_df.merge(join_summoners[['puuid','summonerName','division_tier']],left_on='puuid', right_on ='puuid')

# %%
game_df.to_csv('./datasets/full_data.csv')

# %%
game_df = pd.read_csv('./datasets/base_data.csv')

# %%
game_df
# Out:
#       Unnamed: 0                                          companion  \
# 0              2  {'content_ID': 'b1299bd0-b2e3-4b60-bdf6-a66d38...
# 1             14  {'content_ID': '5897ad9f-4665-4372-8f3e-6c878a...
# 2             20  {'content_ID': '5897ad9f-4665-4372-8f3e-6c878a...
# 3             31  {'content_ID': 'eb78f626-c11a-480e-adeb-ed68af...
# 4             32  {'content_ID': '5897ad9f-4665-4372-8f3e-6c878a...
# ...          ...                                                ...
# 1303        9793  {'content_ID': 'ed36d2bf-1a8e-45b0-bbf3-a3424d...
# 1304        9805  {'content_ID': '5897ad9f-4665-4372-8f3e-6c878a...
# 1305        9810  {'content_ID': 'b36d46ca-120e-4a74-8420-6a10ce...
# 1306        9820  {'content_ID': '5897ad9f-4665-4372-8f3e-6c878a...
# 1307        9835  {'content_ID': '1417c8b3-9ebb-4d56-b9cf-6cb3af...
#
#       gold_left  last_round  level  placement  players_eliminated  \
# 0             1          34      7          3                   0
# 1             1          30      7          5                   0
# 2             3          33      8          2                   0
# 3             2          23      7          8                   0
# 4             0          27      7          6                   0
# ...         ...         ...    ...        ...                 ...
# 1303          0          38      9          2                   2
# 1304          1          27      8          6                   0
# 1305        128          18      5          8                   0
# 1306          5          26      8          7                   0
# 1307          0          26      8          7                   0
#
#                                                   puuid  time_eliminated  \
# 0     Ki1KO62ygcycSVm6LoqHuxrL2CMzEF-bU2uMKrms9pPUog...      1957.186768
# 1     Qo8MH3V2TR24SNwj15PHwdLnmls1zV2TshFuMzLrwoK30-...      1674.880737
# 2     rOLjK2bI7u1Vgf0UW6N57SMSE26R_-Q5sNj5CCYLNPhzCu...      1815.009277
# 3     PhT-sWyWBFP7e9ks7BgJ-jJ4tbI1Pu9g_YqQWf4v-pWQJb...      1226.217285
# 4     NaxTv335VOuWqE47Re-qtlj6IFINYFe9mO0pH_lYndCdlF...      1502.661987
# ...                                                 ...              ...
# 1303  Jam1tBKpzgNOF6iaofZpsaWgsCdPF1OxE8owSS4MXdNSSn...      2206.770020
# 1304  DYjiQdjHWTVN2XlJ6nV34hncu9D1m-B1pzTTtlzkMcw9ls...      1558.788696
# 1305  us2v-tssgxbOQ0FuHRzd-aGwsfB2ln6FstsXjWR4U80Lkr...       979.787964
# 1306  CKyOy5ZYY4dNJJSV0fRg-B1sQpguLlPCk1w2dYE5AnXD5D...      1464.454956
# 1307  XfKiI7h3NVoK_v9A46CDoxw4uo8b6LkO-V_H-d5aHGLii1...      1443.390503
#
#       total_damage_to_players  ... Warden_3 Wind_0 Wind_1 Wind_2  Wind_3  \
# 0                         108  ...        0      0      0      0       0
# 1                          68  ...        0      0      0      0       0
# 2                         128  ...        0      1      0      0       0
# 3                          21  ...        0      1      0      0       0
# 4                          38  ...        0      0      0      0       0
# ...                       ...  ...      ...    ...    ...    ...     ...
# 1303                      138  ...        0      0      0      0       0
# 1304                       58  ...        0      0      0      0       0
# 1305                        0  ...        0      1      0      0       0
# 1306                       37  ...        0      0      0      0       0
# 1307                       34  ...        0      0      0      0       0
#
#       Woodland_0  Woodland_1  Woodland_2      summonerName  division_tier
# 0              1           0           0     Thesmokingpun         IRON_I
# 1              0           0           0   TwitchDrDescend         IRON_I
# 2              0           0           0            Iskoog         IRON_I
# 3              0           0           0  paybackisthename         IRON_I
# 4              0           0           0      Dasheng Tian         IRON_I
# ...          ...         ...         ...               ...            ...
# 1303           0           0           0          SadGam3r      DIAMOND_I
# 1304           0           0           0        Miss Lunar      DIAMOND_I
# 1305           1           0           0            Igoaff      DIAMOND_I
# 1306           0           0           0            h3li0n      DIAMOND_I
# 1307           0           0           0  twitch tv guffee      DIAMOND_I
#
# [1308 rows x 249 columns]

# %%
# RANK values? need to change dia -> bronze : 10 -> 1?

# %%
game_df.describe()
# Out:
#         Unnamed: 0    gold_left   last_round        level    placement  \
# count  1308.000000  1308.000000  1308.000000  1308.000000  1308.000000
# mean   5107.415138     9.317278    31.096330     7.627676     4.586391
# std    2897.326781    19.238433     5.499382     0.893605     2.369346
# min       2.000000     0.000000    11.000000     4.000000     1.000000
# 25%    2591.500000     1.000000    27.000000     7.000000     2.000000
# 50%    5165.500000     2.000000    31.000000     8.000000     5.000000
# 75%    7667.250000     9.000000    35.000000     8.000000     7.000000
# max    9835.000000   156.000000    45.000000     9.000000     8.000000
#
#        players_eliminated  time_eliminated  total_damage_to_players  \
# count         1308.000000      1308.000000              1308.000000
# mean             0.824924      1766.574700               100.142202
# std              1.135404       309.847805                57.365948
# min              0.000000       601.751099                 0.000000
# 25%              0.000000      1562.230133                56.000000
# 50%              0.000000      1784.248657                91.000000
# 75%              1.000000      1987.207397               139.000000
# max              5.000000      2475.402344               272.000000
#
#           Aatrox_1     Aatrox_2  ...     Warden_1     Warden_2     Warden_3  \
# count  1308.000000  1308.000000  ...  1308.000000  1308.000000  1308.000000
# mean      0.015291     0.105505  ...     0.358563     0.090214     0.014526
# std       0.122753     0.307320  ...     0.479762     0.286598     0.119691
# min       0.000000     0.000000  ...     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000  ...     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000  ...     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000  ...     1.000000     0.000000     0.000000
# max       1.000000     1.000000  ...     1.000000     1.000000     1.000000
#
#             Wind_0       Wind_1       Wind_2       Wind_3   Woodland_0  \
# count  1308.000000  1308.000000  1308.000000  1308.000000  1308.000000
# mean      0.095566     0.084862     0.016055     0.006881     0.078746
# std       0.294107     0.278783     0.125735     0.082696     0.269445
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     0.000000     0.000000     0.000000
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#         Woodland_1   Woodland_2
# count  1308.000000  1308.000000
# mean      0.053517     0.000765
# std       0.225148     0.027650
# min       0.000000     0.000000
# 25%       0.000000     0.000000
# 50%       0.000000     0.000000
# 75%       0.000000     0.000000
# max       1.000000     1.000000
#
# [8 rows x 241 columns]
