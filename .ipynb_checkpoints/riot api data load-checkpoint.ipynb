# %%
import pandas as pd
import numpy as np
import requests
import json
from pandas.io.json import json_normalize

# %%
# Global Variables
KEY = 'RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe'
API_BASE = 'https://na1.api.riotgames.com/'
API_BASE_REGION = 'https://americas.api.riotgames.com/'

TIERS = ['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'DIAMOND']
DIVISIONS = ['I', 'II', 'III', 'IV']
TIERS_LIST = []
for tier in TIERS:
  for division in DIVISIONS:
    TIER_DIVISION = tier + '/' + division
    TIERS_LIST.append(TIER_DIVISION)

TIER_URLS = []
for tiers_divis in TIERS_LIST: 
  url = API_BASE + 'tft/league/v1/entries/' + tiers_divis + '?page=1&api_key=' + KEY
  TIER_URLS.append(url)

# %%
TIER_URLS
# Out:
# ['https://na1.api.riotgames.com/tft/league/v1/entries/IRON/I?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/IRON/II?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/IRON/III?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/IRON/IV?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/BRONZE/I?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/BRONZE/II?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/BRONZE/III?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/BRONZE/IV?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/SILVER/I?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/SILVER/II?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/SILVER/III?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/SILVER/IV?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/GOLD/I?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/GOLD/II?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/GOLD/III?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/GOLD/IV?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/PLATINUM/I?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/PLATINUM/II?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/PLATINUM/III?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/PLATINUM/IV?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/DIAMOND/I?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/DIAMOND/II?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/DIAMOND/III?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe',
#  'https://na1.api.riotgames.com/tft/league/v1/entries/DIAMOND/IV?page=1&api_key=RGAPI-4fce3631-38f7-48fb-b15d-23e82aaad4fe']

# %%
# Get list of each summoner in each tier
tier_frames = []

for url in TIER_URLS:
  REQUEST_TIERS = requests.get(url)
  tier_data = json.loads(REQUEST_TIERS.text)
  #each_tier_data = pd.DataFrame(tier_data)
  tier_df = json_normalize(tier_data)
  tier_frames.append(tier_df)
divisions = pd.concat(tier_frames, ignore_index=True, sort=True)

# %%
divisions['tier'].value_counts()
# Out:
# GOLD        820
# IRON        820
# SILVER      820
# DIAMOND     820
# BRONZE      820
# PLATINUM    820
# Name: tier, dtype: int64

# %%
# Get summoner name from divisions data frame / keeping it at 5 for now for testing
summoner_names = divisions.loc[ :5, 'summonerName' ]

# %%
summoner_names
# Out:
# 0       Thesmokingpun
# 1              Iskoog
# 2    paybackisthename
# 3        Dasheng Tian
# 4        KetherEheieh
# 5        Cutesnowball
# Name: summonerName, dtype: object

# %%
summoner_frames = []


for summoner in summoner_names:
  summoner_url = API_BASE + 'tft/summoner/v1/summoners/by-name/' + summoner + '?api_key=' + KEY
  REQUEST_NAME = requests.get(summoner_url)
  summoner_data = json.loads(REQUEST_NAME.text)
  summoner_df = json_normalize(summoner_data)
  summoner_frames.append(summoner_df)
join_summoners = pd.concat(summoner_frames, ignore_index=True, sort=True)

# %%
# Get puuid from summoners data frame
summoner_puuid = join_summoners.loc[ : , 'puuid' ]

# %%
summoner_puuid
# Out:
# 0    Ki1KO62ygcycSVm6LoqHuxrL2CMzEF-bU2uMKrms9pPUog...
# 1    rOLjK2bI7u1Vgf0UW6N57SMSE26R_-Q5sNj5CCYLNPhzCu...
# 2    PhT-sWyWBFP7e9ks7BgJ-jJ4tbI1Pu9g_YqQWf4v-pWQJb...
# 3    NaxTv335VOuWqE47Re-qtlj6IFINYFe9mO0pH_lYndCdlF...
# 4    8DBv1UM_lAtNVyzB8mcRphjnMR8wkLn7V_Mh4AdA0uGlPe...
# 5    DLKIufhvwZXVdJB_2m6toyxzwQmhul4ug2gJH0VUIx4lkQ...
# Name: puuid, dtype: object

# %%
game_id_frames = []
match_count = '10'

for puuid in summoner_puuid:
  match_url = API_BASE_REGION + '/tft/match/v1/matches/by-puuid/' + puuid + '/ids?count=' + match_count + '&api_key=' + KEY
  REQUEST_MATCH = requests.get(match_url)
  match_data = json.loads(REQUEST_MATCH.text)
  match_df = pd.Series(match_data)
  game_id_frames.append(match_df)
game_id_data = pd.concat(game_id_frames, ignore_index=True, sort=True)

# %%
# need to convert to series
game_id_list = game_id_data.loc[:]

# %%
game_id_list
# Out:
# 0     NA1_3220227240
# 1     NA1_3220162612
# 2     NA1_3220139611
# 3     NA1_3220134523
# 4     NA1_3216248085
# 5     NA1_3206202081
# 6     NA1_3205100027
# 7     NA1_3204770545
# 8     NA1_3204695608
# 9     NA1_3198848780
# 10    NA1_3302506161
# 11    NA1_3299173512
# 12    NA1_3299156060
# 13    NA1_3296690355
# 14    NA1_3296635864
# 15    NA1_3296612136
# 16    NA1_3296199597
# 17    NA1_3296214896
# 18    NA1_3296181354
# 19    NA1_3305609664
# 20    NA1_3297705649
# 21    NA1_3270923879
# 22    NA1_3255612106
# 23    NA1_3252309384
# 24    NA1_3245282224
# 25    NA1_3281128705
# 26    NA1_3281117239
# 27    NA1_3231143988
# 28    NA1_3230802586
# 29    NA1_3230772471
# 30    NA1_3228998411
# 31    NA1_3228996078
# 32    NA1_3169022204
# 33    NA1_3169019818
# 34    NA1_3158778451
# 35    NA1_3216869253
# 36    NA1_3216825022
# 37    NA1_3216821143
# 38    NA1_3216664606
# 39    NA1_3215833683
# 40    NA1_3215778561
# 41    NA1_3215773032
# 42    NA1_3215747309
# 43    NA1_3215712480
# 44    NA1_3214694108
# 45    NA1_3244904156
# 46    NA1_3244859255
# 47    NA1_3244882983
# 48    NA1_3244851231
# 49    NA1_3244757899
# 50    NA1_3221398438
# 51    NA1_3221403055
# 52    NA1_3221367886
# 53    NA1_3221334326
# 54    NA1_3216894826
# dtype: object

# %%
match_info_frames = []
match_count = '10'

for game_id in game_id_list:
  result_url = API_BASE_REGION + 'tft/match/v1/matches/' + game_id + '?api_key=' + KEY
  REQUEST_RESULT = requests.get(result_url)
  result_data = json.loads(REQUEST_RESULT.text)
  result_df = json_normalize(result_data)
  match_info_frames.append(result_df)
match_info_data = pd.concat(match_info_frames, ignore_index=True, sort=True)

# %%
match_info_data
# Out:
#     info.game_datetime  info.game_length  \
# 0         1.574978e+12       2028.678955
# 1         1.574968e+12       2297.823975
# 2         1.574966e+12       2343.101562
# 3         1.574962e+12       2248.683105
# 4         1.574635e+12       1838.485840
# 5         1.573725e+12       2251.452881
# 6         1.573632e+12       2266.147705
# 7         1.573612e+12       2203.060547
# 8         1.573610e+12       2195.195557
# 9         1.573124e+12       2258.727295
# 10        1.582241e+12       1823.497559
# 11        1.581929e+12       1926.990967
# 12        1.581927e+12       2116.582520
# 13        1.581742e+12       1952.259521
# 14        1.581740e+12       1956.776978
# 15        1.581739e+12       2129.898682
# 16        1.581730e+12       2000.641479
# 17        1.581728e+12       2000.450684
# 18        1.581727e+12       2169.079102
# 19        1.582505e+12       2048.684326
# 20        1.581832e+12       2204.129150
# 21        1.579555e+12       2178.427979
# 22        1.578283e+12       2444.572266
# 23        1.578007e+12       2256.507080
# 24        1.577308e+12       2183.657471
# 25        1.580410e+12       2011.223267
# 26        1.580408e+12       2178.648926
# 27        1.576036e+12       2132.814453
# 28        1.575999e+12       2296.678223
# 29        1.575997e+12       2437.250000
# 30        1.575830e+12       1958.847412
# 31        1.575829e+12       2219.078125
# 32        1.570565e+12       2490.658447
# 33        1.570562e+12       2315.126709
# 34        1.569470e+12       2157.998291
# 35        1.574666e+12       2159.781494
# 36        1.574664e+12       2193.932861
# 37        1.574662e+12       2303.302490
# 38        1.574660e+12       2146.993652
# 39        1.574583e+12       2419.825684
# 40        1.574580e+12       2288.899658
# 41        1.574578e+12       2217.062012
# 42        1.574576e+12       1979.406494
# 43        1.574574e+12       2210.142822
# 44        1.574497e+12       2373.180420
# 45                 NaN               NaN
# 46                 NaN               NaN
# 47                 NaN               NaN
# 48                 NaN               NaN
# 49                 NaN               NaN
# 50                 NaN               NaN
# 51                 NaN               NaN
# 52                 NaN               NaN
# 53                 NaN               NaN
# 54                 NaN               NaN
#
#                                     info.game_version  \
# 0   Version 9.23.299.3089 (Nov 25 2019/17:12:47) [...
# 1   Version 9.23.299.3089 (Nov 25 2019/17:12:47) [...
# 2   Version 9.23.299.3089 (Nov 25 2019/17:12:47) [...
# 3   Version 9.23.299.3089 (Nov 25 2019/17:12:47) [...
# 4   Version 9.23.298.8833 (Nov 21 2019/15:53:50) [...
# 5   Version 9.22.296.5720 (Nov 05 2019/17:59:07) [...
# 6   Version 9.22.296.5720 (Nov 05 2019/17:59:07) [...
# 7   Version 9.22.296.5720 (Nov 05 2019/17:59:07) [...
# 8   Version 9.22.296.5720 (Nov 05 2019/17:59:07) [...
# 9   Version 9.22.296.5720 (Nov 05 2019/17:59:07) [...
# 10  Version 10.4.308.9400 (Feb 14 2020/17:25:03) [...
# 11  Version 10.3.307.7898 (Feb 06 2020/20:39:51) [...
# 12  Version 10.3.307.7898 (Feb 06 2020/20:39:51) [...
# 13  Version 10.3.307.7898 (Feb 06 2020/20:39:51) [...
# 14  Version 10.3.307.7898 (Feb 06 2020/20:39:51) [...
# 15  Version 10.3.307.7898 (Feb 06 2020/20:39:51) [...
# 16  Version 10.3.307.7898 (Feb 06 2020/20:39:51) [...
# 17  Version 10.3.307.7898 (Feb 06 2020/20:39:51) [...
# 18  Version 10.3.307.7898 (Feb 06 2020/20:39:51) [...
# 19  Version 10.4.308.9400 (Feb 14 2020/17:25:03) [...
# 20  Version 10.3.307.7898 (Feb 06 2020/20:39:51) [...
# 21  Version 10.1.303.9385 (Jan 08 2020/13:40:32) [...
# 22  Version 9.24.300.6382 (Dec 06 2019/17:15:05) [...
# 23  Version 9.24.300.6382 (Dec 06 2019/17:15:05) [...
# 24  Version 9.24.300.6382 (Dec 06 2019/17:15:05) [...
# 25  Version 10.2.305.4739 (Jan 21 2020/15:48:11) [...
# 26  Version 10.2.305.4739 (Jan 21 2020/15:48:11) [...
# 27  Version 9.23.299.3089 (Nov 25 2019/17:12:47) [...
# 28  Version 9.23.299.3089 (Nov 25 2019/17:12:47) [...
# 29  Version 9.23.299.3089 (Nov 25 2019/17:12:47) [...
# 30  Version 9.23.299.3089 (Nov 25 2019/17:12:47) [...
# 31  Version 9.23.299.3089 (Nov 25 2019/17:12:47) [...
# 32  Version 9.19.290.8808 (Sep 25 2019/21:14:15) [...
# 33  Version 9.19.290.8808 (Sep 25 2019/21:14:15) [...
# 34  Version 9.19.290.4926 (Sep 23 2019/18:11:17) [...
# 35  Version 9.23.298.8833 (Nov 21 2019/15:53:50) [...
# 36  Version 9.23.298.8833 (Nov 21 2019/15:53:50) [...
# 37  Version 9.23.298.8833 (Nov 21 2019/15:53:50) [...
# 38  Version 9.23.298.8833 (Nov 21 2019/15:53:50) [...
# 39  Version 9.23.298.8833 (Nov 21 2019/15:53:50) [...
# 40  Version 9.23.298.8833 (Nov 21 2019/15:53:50) [...
# 41  Version 9.23.298.8833 (Nov 21 2019/15:53:50) [...
# 42  Version 9.23.298.8833 (Nov 21 2019/15:53:50) [...
# 43  Version 9.23.298.8833 (Nov 21 2019/15:53:50) [...
# 44  Version 9.23.298.8833 (Nov 21 2019/15:53:50) [...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
#
#                                     info.participants  info.queue_id  \
# 0   [{'companion': {'content_ID': 'b5cab758-7194-4...         1100.0
# 1   [{'companion': {'content_ID': '996dcebf-3353-4...         1100.0
# 2   [{'companion': {'content_ID': 'ebf6a5d5-82c6-4...         1100.0
# 3   [{'companion': {'content_ID': '80291587-1078-4...         1100.0
# 4   [{'companion': {'content_ID': 'b1299bd0-b2e3-4...         1100.0
# 5   [{'companion': {'content_ID': 'eb78f626-c11a-4...         1090.0
# 6   [{'companion': {'content_ID': '5897ad9f-4665-4...         1090.0
# 7   [{'companion': {'content_ID': 'b4d0fd5a-82aa-4...         1090.0
# 8   [{'companion': {'content_ID': '8c27f67c-90b3-4...         1090.0
# 9   [{'companion': {'content_ID': '71a3817b-a49e-4...         1090.0
# 10  [{'companion': {'content_ID': 'c4508a6f-123d-4...         1100.0
# 11  [{'companion': {'content_ID': '5897ad9f-4665-4...         1100.0
# 12  [{'companion': {'content_ID': '204f511e-3d83-4...         1100.0
# 13  [{'companion': {'content_ID': 'c4508a6f-123d-4...         1100.0
# 14  [{'companion': {'content_ID': '5897ad9f-4665-4...         1100.0
# 15  [{'companion': {'content_ID': '99dc25f5-8e2a-4...         1100.0
# 16  [{'companion': {'content_ID': '5897ad9f-4665-4...         1100.0
# 17  [{'companion': {'content_ID': '5897ad9f-4665-4...         1100.0
# 18  [{'companion': {'content_ID': '8c27f67c-90b3-4...         1100.0
# 19  [{'companion': {'content_ID': '5897ad9f-4665-4...         1100.0
# 20  [{'companion': {'content_ID': '32a2fbb4-fa27-4...         1100.0
# 21  [{'companion': {'content_ID': '5897ad9f-4665-4...         1090.0
# 22  [{'companion': {'content_ID': 'a8cca427-0ee2-4...         1100.0
# 23  [{'companion': {'content_ID': '48cd7725-a66e-4...         1100.0
# 24  [{'companion': {'content_ID': 'e21d0481-7788-4...         1100.0
# 25  [{'companion': {'content_ID': '5897ad9f-4665-4...         1100.0
# 26  [{'companion': {'content_ID': '5897ad9f-4665-4...         1100.0
# 27  [{'companion': {'content_ID': '51308483-ce6c-4...         1100.0
# 28  [{'companion': {'content_ID': '6054d70b-e401-4...         1100.0
# 29  [{'companion': {'content_ID': '5897ad9f-4665-4...         1100.0
# 30  [{'companion': {'content_ID': '51308483-ce6c-4...         1100.0
# 31  [{'companion': {'content_ID': 'b500e7da-20b4-4...         1100.0
# 32  [{'companion': {'content_ID': '8c27f67c-90b3-4...         1090.0
# 33  [{'companion': {'content_ID': '5897ad9f-4665-4...         1090.0
# 34  [{'companion': {'content_ID': 'eb78f626-c11a-4...         1090.0
# 35  [{'companion': {'content_ID': '40d843f3-7441-4...         1100.0
# 36  [{'companion': {'content_ID': '8c27f67c-90b3-4...         1100.0
# 37  [{'companion': {'content_ID': '6166ada4-50c8-4...         1100.0
# 38  [{'companion': {'content_ID': '5897ad9f-4665-4...         1100.0
# 39  [{'companion': {'content_ID': '00073b85-7a56-4...         1100.0
# 40  [{'companion': {'content_ID': '8c82996d-a343-4...         1100.0
# 41  [{'companion': {'content_ID': 'ecb13a09-d4f3-4...         1100.0
# 42  [{'companion': {'content_ID': 'eb78f626-c11a-4...         1100.0
# 43  [{'companion': {'content_ID': '51308483-ce6c-4...         1100.0
# 44  [{'companion': {'content_ID': 'd742385a-0f6b-4...         1100.0
# 45                                                NaN            NaN
# 46                                                NaN            NaN
# 47                                                NaN            NaN
# 48                                                NaN            NaN
# 30  [PUUmcMqtRDRVzkCT7ogF48uGZFU-GTCIC-d7hoBwgRBqP...                  NaN
# 31  [FcSA2XUYYTJHTTdgPwCs8B6c1C32Xv5dMCqGRAIBJCCoX...                  NaN
# 32  [YFpITt2LecgT6TVmeO5PFaSnQ6e1Xs3ctTaJqtx4rbnam...                  NaN
# 33  [onPsUxiMeJDE3gnVAHTDAHClQu4bWvqunal4rkS7eLoiH...                  NaN
# 34  [4d1DKqhqYFWKuATgspUaMDuDJswke2w6qbcrtnwEw29mU...                  NaN
# 35  [70Bp79vt4NTj0fd55uQbYPOoXeC-yCxfEFuE6Cz8eF_HU...                  NaN
# 36  [tNQBIFVG6kSCFL_0fDkhC-R7ngS8-De_tN09hmMj1zhlI...                  NaN
# 37  [M2axW0NvEAehSUEIlXiBpNmdV3OXh2iEBfUY_dwvbiYz9...                  NaN
# 38  [kYyVw3--GWl6_nFDN693HpyDZKbR7wWD-dtVdkfzxsN0q...                  NaN
# 39  [WqRHd7EI-n8b44J2Mq8fN5AQZ7skEbt_9PZqv8ChARWSp...                  NaN
# 40  [dtmJvBRrXyF7GeZCcJYrh1fopAtdr4qkzw5FhTHHW1uXg...                  NaN
# 41  i2tOZL4MmvRPTQI_JmlSEBE8T9ax9SUZ7-wfjO-oMOZ...                  NaN
# 42  [KJwgL-don1YLID3Yj-yUfx1bnIELapiJl1WW_tNCSbDtw...                  NaN
# 43  [yO4Ii1cOQZEW70aUaDGAZ_EzfI653AcHcx_brpwx9E-1p...                  NaN
# 44  [g9_YqYVJZMjADBiN6HR7_ZHFkd_aZcKtUWeVr_EJRAOK8...                  NaN
# 45                                                NaN  Rate limit exceeded
# 46                                                NaN  Rate limit exceeded
# 47                                                NaN  Rate limit exceeded
# 48                                                NaN  Rate limit exceeded
# 49                                                NaN  Rate limit exceeded
# 50                                                NaN  Rate limit exceeded
# 51                                                NaN  Rate limit exceeded
# 52                                                NaN  Rate limit exceeded
# 53                                                NaN  Rate limit exceeded
# 54                                                NaN  Rate limit exceeded
#
#     status.status_code
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                  NaN
# 9                  NaN
# 10                 NaN
# 11                 NaN
# 12                 NaN
# 13                 NaN
# 14                 NaN
# 15                 NaN
# 16                 NaN
# 17                 NaN
# 18                 NaN
# 19                 NaN
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31                 NaN
# 32                 NaN
# 33                 NaN
# 34                 NaN
# 35                 NaN
# 36                 NaN
# 37                 NaN
# 38                 NaN
# 39                 NaN
# 40                 NaN
# 41                 NaN
# 42                 NaN
# 43                 NaN
# 44                 NaN
# 45               429.0
# 46               429.0
# 47               429.0
# 48               429.0
# 49               429.0
# 50               429.0
# 51               429.0
# 52               429.0
# 53               429.0
# 54               429.0
