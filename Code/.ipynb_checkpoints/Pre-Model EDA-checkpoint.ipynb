# %% [markdown]
# # Pre-Model EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# from matplotlib_venn import venn2

# %%
game_df = pd.read_csv('../datasets/base_data.csv')

# %%
game_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9840 entries, 0 to 9839
# Columns: 247 entries, Unnamed: 0 to Woodland_2
# dtypes: float64(1), int64(240), object(6)
# memory usage: 18.5+ MB

# %%
game_df.describe().T
# Out:
#              count         mean          std   min      25%     50%      75%  \
# Unnamed: 0  9840.0  4919.500000  2840.707658   0.0  2459.75  4919.5  7379.25
# gold_left   9840.0     9.685671    17.451114   0.0     1.00     2.0    11.00
# last_round  9840.0    31.279675     5.103466  11.0    27.00    31.0    35.00
# level       9840.0     7.657012     0.856239   4.0     7.00     8.0     8.00
# placement   9840.0     4.500000     2.291404   1.0     2.75     4.5     6.25
# ...            ...          ...          ...   ...      ...     ...      ...
# Wind_2      9840.0     0.012093     0.109309   0.0     0.00     0.0     0.00
# Wind_3      9840.0     0.005894     0.076552   0.0     0.00     0.0     0.00
# Woodland_0  9840.0     0.078557     0.269060   0.0     0.00     0.0     0.00
# Woodland_1  9840.0     0.055996     0.229926   0.0     0.00     0.0     0.00
# Woodland_2  9840.0     0.002439     0.049329   0.0     0.00     0.0     0.00
#
#                max
# Unnamed: 0  9839.0
# ...

# %%
# summary statistics of players with high placements (1 or 2)
game_df[game_df['placement']<= 2].describe().T
# Out:
#              count         mean          std   min     25%     50%      75%  \
# Unnamed: 0  2460.0  4919.489837  2841.084591   5.0  2459.5  4918.0  7379.25
# gold_left   2460.0     6.984146    11.276163   0.0     1.0     2.0     8.00
# last_round  2460.0    37.203252     2.370207  31.0    35.0    37.0    38.00
# level       2460.0     8.258130     0.661830   6.0     8.0     8.0     9.00
# placement   2460.0     1.500000     0.500102   1.0     1.0     1.5     2.00
# ...            ...          ...          ...   ...     ...     ...      ...
# Wind_2      2460.0     0.017073     0.129570   0.0     0.0     0.0     0.00
# Wind_3      2460.0     0.011789     0.107955   0.0     0.0     0.0     0.00
# Woodland_0  2460.0     0.071951     0.258460   0.0     0.0     0.0     0.00
# Woodland_1  2460.0     0.043902     0.204920   0.0     0.0     0.0     0.00
# Woodland_2  2460.0     0.004472     0.066734   0.0     0.0     0.0     0.00
#
#                max
# Unnamed: 0  9839.0
# ...

# %%
# summary statistics of players with low placements (7 or 8)
game_df[game_df['placement']>= 7].describe().T
# Out:
#              count         mean          std   min      25%     50%     75%  \
# Unnamed: 0  2460.0  4919.483333  2841.130034   3.0  2456.75  4919.0  7376.5
# gold_left   2460.0    15.930894    25.744816   0.0     1.00     4.0    21.0
# last_round  2460.0    25.139431     3.013672  11.0    24.00    26.0    27.0
# level       2460.0     7.006504     0.840200   4.0     7.00     7.0     8.0
# placement   2460.0     7.500000     0.500102   7.0     7.00     7.5     8.0
# ...            ...          ...          ...   ...      ...     ...     ...
# Wind_2      2460.0     0.009350     0.096260   0.0     0.00     0.0     0.0
# Wind_3      2460.0     0.002033     0.045047   0.0     0.00     0.0     0.0
# Woodland_0  2460.0     0.093902     0.291752   0.0     0.00     0.0     0.0
# Woodland_1  2460.0     0.048780     0.215453   0.0     0.00     0.0     0.0
# Woodland_2  2460.0     0.000407     0.020162   0.0     0.00     0.0     0.0
#
#                max
# Unnamed: 0  9835.0
# ...

# %%
# NEED TO AUTOMATE

# subset list of team compositions + frequency for players with high placement (1)
placement_1_df = game_df[game_df['placement'] == 1]
placement_1_df = placement_1_df.sum()
placement_1_df = pd.DataFrame(placement_1_df)
placement_1_list = placement_1_df.iloc[13:]

# remove range = 0 REMEMBER
#for num in range(8)

# subset list of team compositions + frequency for players with average placement (2)
placement_2_df = game_df[game_df['placement'] == 2]
placement_2_df = placement_2_df.sum()
placement_2_df = pd.DataFrame(placement_2_df)
placement_2_list = placement_2_df.iloc[13:]

placement_3_df = game_df[game_df['placement'] == 3]
placement_3_df = placement_3_df.sum()
placement_3_df = pd.DataFrame(placement_3_df)
placement_3_list = placement_3_df.iloc[13:]

placement_4_df = game_df[game_df['placement'] == 4]
placement_4_df = placement_4_df.sum()
placement_4_df = pd.DataFrame(placement_4_df)
placement_4_list = placement_4_df.iloc[13:]


# ???????????
placement_5_df = game_df[game_df['placement'] == 5]
placement_5_df = placement_5_df.sum()
placement_5_df = pd.DataFrame(placement_5_df)
placement_5_list = placement_5_df.iloc[14:]

placement_6_df = game_df[game_df['placement'] == 6]
placement_6_df = placement_6_df.sum()
placement_6_df = pd.DataFrame(placement_6_df)
placement_6_list = placement_6_df.iloc[13:]

placement_7_df = game_df[game_df['placement'] == 7]
placement_7_df = placement_7_df.sum()
placement_7_df = pd.DataFrame(placement_7_df)
placement_7_list = placement_7_df.iloc[13:]

placement_8_df = game_df[game_df['placement'] == 8]
placement_8_df = placement_8_df.sum()
placement_8_df = pd.DataFrame(placement_8_df)
placement_8_list = placement_8_df.iloc[13:]

# %%
# change the index and sort values to have individual lists of most used combinations

placement_1_list = placement_1_list.reset_index()
placement_1_list.rename( columns={'index' : 'combination', 0 :'count'}, inplace=True )
placement_1_list.sort_values(by = 'count', ascending=False, inplace = True)

placement_2_list = placement_2_list.reset_index()
placement_2_list.rename( columns={'index' : 'combination', 0 :'count'}, inplace=True )
placement_2_list.sort_values(by = 'count', ascending=False, inplace = True)

placement_3_list = placement_3_list.reset_index()
placement_3_list.rename( columns={'index' : 'combination', 0 :'count'}, inplace=True )
placement_3_list.sort_values(by = 'count', ascending=False, inplace = True)

placement_4_list = placement_4_list.reset_index()
placement_4_list.rename( columns={'index' : 'combination', 0 :'count'}, inplace=True )
placement_4_list.sort_values(by = 'count', ascending=False, inplace = True)

placement_5_list = placement_5_list.reset_index()
placement_5_list.rename( columns={'index' : 'combination', 0 :'count'}, inplace=True )
placement_5_list.sort_values(by = 'count', ascending=False, inplace = True)

placement_6_list = placement_6_list.reset_index()
placement_6_list.rename( columns={'index' : 'combination', 0 :'count'}, inplace=True )
placement_6_list.sort_values(by = 'count', ascending=False, inplace = True)

placement_7_list = placement_7_list.reset_index()
placement_7_list.rename( columns={'index' : 'combination', 0 :'count'}, inplace=True )
placement_7_list.sort_values(by = 'count', ascending=False, inplace = True)

placement_8_list = placement_8_list.reset_index()
placement_8_list.rename( columns={'index' : 'combination', 0 :'count'}, inplace=True )
placement_8_list.sort_values(by = 'count', ascending=False, inplace = True)

# %%
print(placement_1_list.shape)
print(placement_2_list.shape)
print(placement_3_list.shape)
print(placement_4_list.shape)
print(placement_5_list.shape)
print(placement_6_list.shape)
print(placement_7_list.shape)
print(placement_8_list.shape)
# Out:
# (233, 2)
# (232, 2)
# (233, 2)
# (233, 2)
# (233, 2)
# (233, 2)
# (232, 2)
# (232, 2)

# %%
# code snippet from my reddit classification project
# AUTOMATE
plt.figure(figsize = (32,22))

sns.set_style("whitegrid")
sns.set(font_scale = 2)

ax1 = plt.subplot(421)
ax1.set_xlabel('count', fontsize=25)
ax1.set_ylabel('combination', fontsize=25)
ax1.set_title('Placement : 1',fontsize = 30)
ax1 = sns.barplot(data=placement_1_list.head(10),x='count',y='combination',orient='h')

ax1 = plt.subplot(422)
ax1.set_xlabel('count', fontsize=25)
ax1.set_ylabel('combination', fontsize=25)
ax1.set_title('Placement : 2',fontsize = 30)
ax1 = sns.barplot(data=placement_2_list.head(10),x='count',y='combination',orient='h')

ax1 = plt.subplot(423)
ax1.set_xlabel('count', fontsize=25)
ax1.set_ylabel('combination', fontsize=25)
ax1.set_title('Placement : 3',fontsize = 30)
ax1 = sns.barplot(data=placement_3_list.head(10),x='count',y='combination',orient='h')

ax1 = plt.subplot(424)
ax1.set_xlabel('count', fontsize=25)
ax1.set_ylabel('combination', fontsize=25)
ax1.set_title('Placement : 4',fontsize = 30)
ax1 = sns.barplot(data=placement_4_list.head(10),x='count',y='combination',orient='h')

ax1 = plt.subplot(425)
ax1.set_xlabel('count', fontsize=25)
ax1.set_ylabel('combination', fontsize=25)
ax1.set_title('Placement : 5',fontsize = 30)
ax1 = sns.barplot(data=placement_5_list.head(10),x='count',y='combination',orient='h')

ax1 = plt.subplot(426)
ax1.set_xlabel('count', fontsize=25)
ax1.set_ylabel('combination', fontsize=25)
ax1.set_title('Placement : 6',fontsize = 30)
ax1 = sns.barplot(data=placement_6_list.head(10),x='count',y='combination',orient='h')

ax1 = plt.subplot(427)
ax1.set_xlabel('count', fontsize=25)
ax1.set_ylabel('combination', fontsize=25)
ax1.set_title('Placement : 7',fontsize = 30)
ax1 = sns.barplot(data=placement_7_list.head(10),x='count',y='combination',orient='h')

ax1 = plt.subplot(428)
ax1.set_xlabel('count', fontsize=25)
ax1.set_ylabel('combination', fontsize=25)
ax1.set_title('Placement : 8',fontsize = 30)
ax1 = sns.barplot(data=placement_8_list.head(10),x='count',y='combination',orient='h')

plt.tight_layout()
